# %% [markdown]
# ## 数据导入

# %%
import pandas as pd

# 数据加载
train_data = pd.read_csv('./used_car_train_20200313.csv', sep=' ')
test = pd.read_csv("./used_car_testB_20200421.csv", sep = ' ')

# %%
# 输出结果格式设置
result = pd.DataFrame()
result['SaleID'] = test['SaleID']

# %% [markdown]
# ## 异常值，缺失值处理

# %%
train_data['notRepairedDamage'].value_counts()
# Out:
# 0.0    111361
# -       24324
# 1.0     14315
# Name: notRepairedDamage, dtype: int64

# %%
# 处理notRepairedDamage列异常值,数据取值0,1
train_data['notRepairedDamage'].replace('-', '0.0', inplace=True)
test['notRepairedDamage'].replace('-', '0.0', inplace=True)

# %%
# 处理power列异常值,发动机功率：范围 [ 0, 600 ]
train_data['power'][train_data['power']>600] = 600
test['power'][test['power']>600] = 600
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print(train_data.isnull().sum())
print(test.isnull().sum())
# Out:
# SaleID                  0
# name                    0
# regDate                 0
# model                   1
# brand                   0
# bodyType             4506
# fuelType             8680
# gearbox              5981
# power                   0
# kilometer               0
# notRepairedDamage       0
# regionCode              0
# seller                  0
# offerType               0
# creatDate               0
# price                   0
# v_0                     0
# v_1                     0
# v_2                     0
# v_3                     0
# v_4                     0
# v_5                     0
# v_6                     0
# v_7                     0
# v_8                     0
# v_9                     0
# v_10                    0
# v_11                    0
# v_12                    0
# v_13                    0
# v_14                    0
# dtype: int64
# SaleID                  0
# name                    0
# regDate                 0
# model                   0
# brand                   0
# bodyType             1504
# fuelType             2924
# gearbox              1968
# power                   0
# kilometer               0
# notRepairedDamage       0
# regionCode              0
# seller                  0
# offerType               0
# creatDate               0
# v_0                     0
# v_1                     0
# v_2                     0
# v_3                     0
# v_4                     0
# v_5                     0
# v_6                     0
# v_7                     0
# v_8                     0
# v_9                     0
# v_10                    0
# v_11                    0
# v_12                    0
# v_13                    0
# v_14                    0
# dtype: int64

# %%
# 缺失值处理，众数填充
train_data['model'].fillna(train_data['model'].mode()[0],inplace=True)
train_data['bodyType'].fillna(train_data['bodyType'].mode()[0],inplace=True)
test['bodyType'].fillna(test['bodyType'].mode()[0],inplace=True)
train_data['fuelType'].fillna(train_data['fuelType'].mode()[0],inplace=True)
test['fuelType'].fillna(test['fuelType'].mode()[0],inplace=True)
train_data['gearbox'].fillna(train_data['gearbox'].mode()[0],inplace=True)
test['gearbox'].fillna(test['gearbox'].mode()[0],inplace=True)

# %% [markdown]
# ## 对日期格式进行处理

# %%
train_data_regDate_New = []
for i in train_data['regDate']:
    j = str(i)
    if j[4:6] == '00': i +=100
    train_data_regDate_New.append(i)
test_regDate_New = []
for i in test['regDate']:
    j = str(i)
    if j[4:6] == '00': i +=100
    test_regDate_New.append(i)
train_data['regDate'] = train_data_regDate_New
test['regDate'] = test_regDate_New

# %%
train_data['regDate'] = pd.to_datetime(train_data['regDate'],format='%Y%m%d',errors='coerce')
test['regDate'] = pd.to_datetime(test['regDate'],format='%Y%m%d',errors='coerce')
train_data['creatDate'] = pd.to_datetime(train_data['creatDate'],format='%Y%m%d',errors='coerce')
test['creatDate'] = pd.to_datetime(test['creatDate'],format='%Y%m%d',errors='coerce')

# %%
# 时间多尺度
train_data['regDate_year'] = train_data['regDate'].apply(lambda x: str(x)[0:4])
train_data['regDate_month'] = train_data['regDate'].apply(lambda x: str(x)[5:7])
train_data['regDate_day'] = train_data['regDate'].apply(lambda x: str(x)[8:10])
print(train_data[['regDate', 'regDate_year', 'regDate_month', 'regDate_day']])

test['regDate_year'] = test['regDate'].apply(lambda x: str(x)[0:4])
test['regDate_month'] = test['regDate'].apply(lambda x: str(x)[5:7])
test['regDate_day'] = test['regDate'].apply(lambda x: str(x)[8:10])
print(test[['regDate', 'regDate_year', 'regDate_month', 'regDate_day']])

train_data['creatDate_year'] = train_data['creatDate'].apply(lambda x: str(x)[0:4])
train_data['creatDate_month'] = train_data['creatDate'].apply(lambda x: str(x)[5:7])
train_data['creatDate_day'] = train_data['creatDate'].apply(lambda x: str(x)[8:10])
print(train_data[['creatDate', 'creatDate_year', 'creatDate_month', 'creatDate_day']])

test['creatDate_year'] = test['creatDate'].apply(lambda x: str(x)[0:4])
test['creatDate_month'] = test['creatDate'].apply(lambda x: str(x)[5:7])
test['creatDate_day'] = test['creatDate'].apply(lambda x: str(x)[8:10])
print(test[['creatDate', 'creatDate_year', 'creatDate_month', 'creatDate_day']])
# Out:
#           regDate regDate_year regDate_month regDate_day
# 0      2004-04-02         2004            04          02
# 1      2003-03-01         2003            03          01
# 2      2004-04-03         2004            04          03
# 3      1996-09-08         1996            09          08
# 4      2012-01-03         2012            01          03
# ...           ...          ...           ...         ...
# 149995 2000-06-07         2000            06          07
# 149996 2009-11-02         2009            11          02
# 149997 2010-10-03         2010            10          03
# 149998 2006-03-12         2006            03          12
# 149999 1999-02-04         1999            02          04
#
# [150000 rows x 4 columns]
#          regDate regDate_year regDate_month regDate_day
# 0     2000-05-01         2000            05          01
# 1     1995-02-11         1995            02          11
# 2     2009-06-06         2009            06          06
# 3     2002-06-01         2002            06          01
# 4     2003-03-01         2003            03          01
# ...          ...          ...           ...         ...
# 49995 2004-10-05         2004            10          05
# 49996 2013-04-09         2013            04          09
# 49997 2004-12-11         2004            12          11
# 49998 2002-07-02         2002            07          02
# 49999 2009-07-08         2009            07          08
#
# [50000 rows x 4 columns]
#         creatDate creatDate_year creatDate_month creatDate_day
# 0      2016-04-04           2016              04            04
# 1      2016-03-09           2016              03            09
# 2      2016-04-02           2016              04            02
# 3      2016-03-12           2016              03            12
# 4      2016-03-13           2016              03            13
# ...           ...            ...             ...           ...
# 149995 2016-03-27           2016              03            27
# 149996 2016-03-12           2016              03            12
# 149997 2016-03-28           2016              03            28
# 149998 2016-04-01           2016              04            01
# 149999 2016-03-05           2016              03            05
#
# [150000 rows x 4 columns]
#        creatDate creatDate_year creatDate_month creatDate_day
# 0     2016-03-08           2016              03            08
# 1     2016-03-10           2016              03            10
# 2     2016-03-09           2016              03            09
# 3     2016-03-14           2016              03            14
# 4     2016-03-06           2016              03            06
# ...          ...            ...             ...           ...
# 49995 2016-03-09           2016              03            09
# 49996 2016-03-23           2016              03            23
# 49997 2016-03-16           2016              03            16
# 49998 2016-03-27           2016              03            27
# 49999 2016-04-01           2016              04            01
#
# [50000 rows x 4 columns]

# %%
# 时间diff
train_data['regDate_diff'] = (train_data['regDate'] - train_data['regDate'].min()).dt.days
test['regDate_diff'] = (test['regDate'] - train_data['regDate'].min()).dt.days
train_data['creatDate_diff'] = (train_data['creatDate'] - train_data['creatDate'].min()).dt.days
test['creatDate_diff'] = (test['creatDate'] - train_data['creatDate'].min()).dt.days
print(train_data[['regDate', 'regDate_diff']])
print(test[['regDate', 'regDate_diff']])
print(train_data[['creatDate', 'creatDate_diff']])
print(test[['creatDate', 'creatDate_diff']])
# Out:
#           regDate  regDate_diff
# 0      2004-04-02          4840
# 1      2003-03-01          4442
# 2      2004-04-03          4841
# 3      1996-09-08          2077
# 4      2012-01-03          7672
# ...           ...           ...
# 149995 2000-06-07          3445
# 149996 2009-11-02          6880
# 149997 2010-10-03          7215
# 149998 2006-03-12          5549
# 149999 1999-02-04          2956
#
# [150000 rows x 2 columns]
#          regDate  regDate_diff
# 0     2000-05-01          3408
# 1     1995-02-11          1502
# 2     2009-06-06          6731
# 3     2002-06-01          4169
# 4     2003-03-01          4442
# ...          ...           ...
# 49995 2004-10-05          5026
# 49996 2013-04-09          8134
# 49997 2004-12-11          5093
# 49998 2002-07-02          4200
# 49999 2009-07-08          6763
#
# [50000 rows x 2 columns]
#         creatDate  creatDate_diff
# 0      2016-04-04             291
# 1      2016-03-09             265
# 2      2016-04-02             289
# 3      2016-03-12             268
# 4      2016-03-13             269
# ...           ...             ...
# 149995 2016-03-27             283
# 149996 2016-03-12             268
# 149997 2016-03-28             284
# 149998 2016-04-01             288
# 149999 2016-03-05             261
#
# [150000 rows x 2 columns]
#        creatDate  creatDate_diff
# 0     2016-03-08             264
# 1     2016-03-10             266
# 2     2016-03-09             265
# 3     2016-03-14             270
# 4     2016-03-06             262
# ...          ...             ...
# 49995 2016-03-09             265
# 49996 2016-03-23             279
# 49997 2016-03-16             272
# 49998 2016-03-27             283
# 49999 2016-04-01             288
#
# [50000 rows x 2 columns]

# %%
print(train_data.isnull().sum())
print(test.isnull().sum())
# Out:
# SaleID               0
# name                 0
# regDate              0
# model                0
# brand                0
# bodyType             0
# fuelType             0
# gearbox              0
# power                0
# kilometer            0
# notRepairedDamage    0
# regionCode           0
# seller               0
# offerType            0
# creatDate            0
# price                0
# v_0                  0
# v_1                  0
# v_2                  0
# v_3                  0
# v_4                  0
# v_5                  0
# v_6                  0
# v_7                  0
# v_8                  0
# v_9                  0
# v_10                 0
# v_11                 0
# v_12                 0
# v_13                 0
# v_14                 0
# regDate_year         0
# regDate_month        0
# regDate_day          0
# creatDate_year       0
# creatDate_month      0
# creatDate_day        0
# regDate_diff         0
# creatDate_diff       0
# dtype: int64
# SaleID               0
# name                 0
# regDate              0
# model                0
# brand                0
# bodyType             0
# fuelType             0
# gearbox              0
# power                0
# kilometer            0
# notRepairedDamage    0
# regionCode           0
# seller               0
# offerType            0
# creatDate            0
# v_0                  0
# v_1                  0
# v_2                  0
# v_3                  0
# v_4                  0
# v_5                  0
# v_6                  0
# v_7                  0
# v_8                  0
# v_9                  0
# v_10                 0
# v_11                 0
# v_12                 0
# v_13                 0
# v_14                 0
# regDate_year         0
# regDate_month        0
# regDate_day          0
# creatDate_year       0
# creatDate_month      0
# creatDate_day        0
# regDate_diff         0
# creatDate_diff       0
# dtype: int64

# %% [markdown]
# ## 增加新的特征，对brand进行统计

# %%
# 增加新的特征，对brand进行统计
# brand_amount, brand_price_max, brand_price_min, brand_price_median, brand_price_sum, brand_price_std, brand_price_mean
brand_data = train_data.groupby('brand')
all_info = {}
for brand_index, brand_temp in brand_data:
    info = {}
    brand_temp = brand_temp[brand_temp['price'] > 0]
    info['brand_amount'] = len(brand_temp)
    info['brand_price_max'] = brand_temp.price.max()
    info['brand_price_min'] = brand_temp.price.min()
    info['brand_price_median'] = brand_temp.price.median()
    info['brand_price_mean'] = brand_temp.price.mean()
    info['brand_price_sum'] = brand_temp.price.sum()
    info['brand_price_std'] = brand_temp.price.std()
    info['brand_price_ptp'] = info['brand_price_max'] - info['brand_price_min']
    all_info[brand_index] = info
all_info
# Out:
# {0: {'brand_amount': 31480,
#   'brand_price_max': 68500,
#   'brand_price_min': 13,
#   'brand_price_median': 3199.0,
#   'brand_price_mean': 5535.36499364676,
#   'brand_price_sum': 174253290,
#   'brand_price_std': 6272.522118575291,
#   'brand_price_ptp': 68487},
#  1: {'brand_amount': 13794,
#   'brand_price_max': 99900,
#   'brand_price_min': 15,
#   'brand_price_median': 6499.0,
#   'brand_price_mean': 9273.31194722343,
#   'brand_price_sum': 127916065,
#   'brand_price_std': 9369.631497175233,
#   'brand_price_ptp': 99885},
#  2: {'brand_amount': 321,
#   'brand_price_max': 59800,
#   'brand_price_min': 35,
#   'brand_price_median': 7700.0,
#   'brand_price_mean': 12037.822429906542,
#   'brand_price_sum': 3864141,
#   'brand_price_std': 10875.892890769717,
#   'brand_price_ptp': 59765},
#  3: {'brand_amount': 2461,
#   'brand_price_max': 37500,
#   'brand_price_min': 65,
#   'brand_price_median': 4990.0,
#   'brand_price_mean': 6482.822429906542,
#   'brand_price_sum': 15954226,
#   'brand_price_std': 5396.32750326748,
#   'brand_price_ptp': 37435},
#  4: {'brand_amount': 16737,
#   'brand_price_max': 99999,
#   'brand_price_min': 12,
#   'brand_price_median': 6000.0,
#   'brand_price_mean': 8538.788074326343,
#   'brand_price_sum': 142913696,
#   'brand_price_std': 8472.393191215217,
#   'brand_price_ptp': 99987},
#  5: {'brand_amount': 4665,
#   'brand_price_max': 31500,
#   'brand_price_min': 20,
#   'brand_price_median': 2300.0,
#   'brand_price_mean': 3306.349410503751,
#   'brand_price_sum': 15424120,
#   'brand_price_std': 3343.6245864799507,
#   'brand_price_ptp': 31480},
#  6: {'brand_amount': 10217,
#   'brand_price_max': 59900,
#   'brand_price_min': 13,
#   'brand_price_median': 1800.0,
#   'brand_price_mean': 3611.840266222962,
#   'brand_price_sum': 36902172,
#   'brand_price_std': 4681.293524484887,
#   'brand_price_ptp': 59887},
#  7: {'brand_amount': 2361,
#   'brand_price_max': 38900,
#   'brand_price_min': 60,
#   'brand_price_median': 2600.0,
#   'brand_price_mean': 4196.064803049555,
#   'brand_price_sum': 9906909,
#   'brand_price_std': 4752.0327761437575,
#   'brand_price_ptp': 38840},
#  8: {'brand_amount': 2077,
#   'brand_price_max': 99999,
#   'brand_price_min': 30,
#   'brand_price_median': 2299.0,
#   'brand_price_mean': 4900.5151661049595,
#   'brand_price_sum': 10178370,
#   'brand_price_std': 6227.035419367086,
#   'brand_price_ptp': 99969},
#  9: {'brand_amount': 7306,
#   'brand_price_max': 68530,
#   'brand_price_min': 50,
#   'brand_price_median': 1400.0,
#   'brand_price_mean': 2438.274842595127,
#   'brand_price_sum': 17814036,
#   'brand_price_std': 2974.2727759352574,
#   'brand_price_ptp': 68480},
#  10: {'brand_amount': 14249,
#   'brand_price_max': 98000,
#   'brand_price_min': 15,
#   'brand_price_median': 5400.0,
#   'brand_price_mean': 8470.804196785739,
#   'brand_price_sum': 120700489,
#   'brand_price_std': 8988.307534531947,
#   'brand_price_ptp': 97985},
#  11: {'brand_amount': 2945,
#   'brand_price_max': 34500,
#   'brand_price_min': 30,
#   'brand_price_median': 2900.0,
#   'brand_price_mean': 4549.73039049236,
#   'brand_price_sum': 13398956,
#   'brand_price_std': 4721.824689756222,
#   'brand_price_ptp': 34470},
#  12: {'brand_amount': 1109,
#   'brand_price_max': 27490,
#   'brand_price_min': 50,
#   'brand_price_median': 2600.0,
#   'brand_price_mean': 4053.789900811542,
#   'brand_price_sum': 4495653,
#   'brand_price_std': 4065.936442379779,
#   'brand_price_ptp': 27440},
#  13: {'brand_amount': 3817,
#   'brand_price_max': 35000,
#   'brand_price_min': 20,
#   'brand_price_median': 1600.0,
#   'brand_price_mean': 2799.957820277705,
#   'brand_price_sum': 10687439,
#   'brand_price_std': 3073.3033552120255,
#   'brand_price_ptp': 34980},
#  14: {'brand_amount': 16089,
#   'brand_price_max': 38990,
#   'brand_price_min': 12,
#   'brand_price_median': 1700.0,
#   'brand_price_mean': 3052.66020262291,
#   'brand_price_sum': 49114250,
#   'brand_price_std': 3605.2402552490803,
#   'brand_price_ptp': 38978},
#  15: {'brand_amount': 1458,
#   'brand_price_max': 45000,
#   'brand_price_min': 100,
#   'brand_price_median': 8500.0,
#   'brand_price_mean': 9858.582990397805,
#   'brand_price_sum': 14373814,
#   'brand_price_std': 5425.058139699541,
#   'brand_price_ptp': 44900},
#  16: {'brand_amount': 2223,
#   'brand_price_max': 17900,
#   'brand_price_min': 20,
#   'brand_price_median': 2999.0,
#   'brand_price_mean': 3644.4453441295545,
#   'brand_price_sum': 8101602,
#   'brand_price_std': 2462.6244833782157,
#   'brand_price_ptp': 17880},
#  17: {'brand_amount': 913,
#   'brand_price_max': 55800,
#   'brand_price_min': 15,
#   'brand_price_median': 2200.0,
#   'brand_price_mean': 3645.869660460022,
#   'brand_price_sum': 3328679,
#   'brand_price_std': 3952.913329849266,
#   'brand_price_ptp': 55785},
#  18: {'brand_amount': 316,
#   'brand_price_max': 34599,
#   'brand_price_min': 50,
#   'brand_price_median': 1999.0,
#   'brand_price_mean': 4872.620253164557,
#   'brand_price_sum': 1539748,
#   'brand_price_std': 6410.8274246023,
#   'brand_price_ptp': 34549},
#  19: {'brand_amount': 1388,
#   'brand_price_max': 42350,
#   'brand_price_min': 20,
#   'brand_price_median': 2800.0,
#   'brand_price_mean': 5209.2132564841495,
#   'brand_price_sum': 7230388,
#   'brand_price_std': 6184.097328975655,
#   'brand_price_ptp': 42330},
#  20: {'brand_amount': 1236,
#   'brand_price_max': 37800,
#   'brand_price_min': 15,
#   'brand_price_median': 1770.0,
#   'brand_price_mean': 3475.596278317152,
#   'brand_price_sum': 4295837,
#   'brand_price_std': 4398.760851970501,
#   'brand_price_ptp': 37785},
#  21: {'brand_amount': 1547,
#   'brand_price_max': 35999,
#   'brand_price_min': 50,
#   'brand_price_median': 4200.0,
#   'brand_price_mean': 5725.553329023917,
#   'brand_price_sum': 8857431,
#   'brand_price_std': 5256.9386314783615,
#   'brand_price_ptp': 35949},
#  22: {'brand_amount': 1085,
#   'brand_price_max': 43900,
#   'brand_price_min': 50,
#   'brand_price_median': 3950.0,
#   'brand_price_mean': 6030.807373271889,
#   'brand_price_sum': 6543426,
#   'brand_price_std': 5877.140886263793,
#   'brand_price_ptp': 43850},
#  23: {'brand_amount': 186,
#   'brand_price_max': 64000,
#   'brand_price_min': 99,
#   'brand_price_median': 1200.0,
#   'brand_price_mean': 3217.9139784946237,
#   'brand_price_sum': 598532,
#   'brand_price_std': 7282.590635957693,
#   'brand_price_ptp': 63901},
#  24: {'brand_amount': 772,
#   'brand_price_max': 99999,
#   'brand_price_min': 15,
#   'brand_price_median': 29990.0,
#   'brand_price_mean': 36202.211139896375,
#   'brand_price_sum': 27948107,
#   'brand_price_std': 22631.173477090717,
#   'brand_price_ptp': 99984},
#  25: {'brand_amount': 2064,
#   'brand_price_max': 22500,
#   'brand_price_min': 25,
#   'brand_price_median': 2500.0,
#   'brand_price_mean': 3647.4496124031007,
#   'brand_price_sum': 7528336,
#   'brand_price_std': 3552.8339627163855,
#   'brand_price_ptp': 22475},
#  26: {'brand_amount': 966,
#   'brand_price_max': 99999,
#   'brand_price_min': 11,
#   'brand_price_median': 5872.5,
#   'brand_price_mean': 11486.618012422361,
#   'brand_price_sum': 11096073,
#   'brand_price_std': 15926.17089537374,
#   'brand_price_ptp': 99988},
#  27: {'brand_amount': 2053,
#   'brand_price_max': 62900,
#   'brand_price_min': 35,
#   'brand_price_median': 4200.0,
#   'brand_price_mean': 5305.990745250852,
#   'brand_price_sum': 10893199,
#   'brand_price_std': 4855.37767740731,
#   'brand_price_ptp': 62865},
#  28: {'brand_amount': 649,
#   'brand_price_max': 44900,
#   'brand_price_min': 80,
#   'brand_price_median': 3900.0,
#   'brand_price_mean': 5798.372881355932,
#   'brand_price_sum': 3763144,
#   'brand_price_std': 5702.771796793247,
#   'brand_price_ptp': 44820},
#  29: {'brand_amount': 406,
#   'brand_price_max': 19990,
#   'brand_price_min': 500,
#   'brand_price_median': 5250.0,
#   'brand_price_mean': 6056.71921182266,
#   'brand_price_sum': 2459028,
#   'brand_price_std': 3639.7377221985953,
#   'brand_price_ptp': 19490},
#  30: {'brand_amount': 940,
#   'brand_price_max': 23200,
#   'brand_price_min': 50,
#   'brand_price_median': 3295.0,
#   'brand_price_mean': 4190.579787234043,
#   'brand_price_sum': 3939145,
#   'brand_price_std': 3659.577291449609,
#   'brand_price_ptp': 23150},
#  31: {'brand_amount': 318,
#   'brand_price_max': 11000,
#   'brand_price_min': 50,
#   'brand_price_median': 1000.0,
#   'brand_price_mean': 1761.493710691824,
#   'brand_price_sum': 560155,
#   'brand_price_std': 1829.0792114585884,
#   'brand_price_ptp': 10950},
#  32: {'brand_amount': 592,
#   'brand_price_max': 33500,
#   'brand_price_min': 50,
#   'brand_price_median': 2399.5,
#   'brand_price_mean': 4119.569256756757,
#   'brand_price_sum': 2438785,
#   'brand_price_std': 4567.345303576133,
#   'brand_price_ptp': 33450},
#  33: {'brand_amount': 218,
#   'brand_price_max': 83990,
#   'brand_price_min': 980,
#   'brand_price_median': 5925.0,
#   'brand_price_mean': 11243.40366972477,
#   'brand_price_sum': 2451062,
#   'brand_price_std': 13491.013523170997,
#   'brand_price_ptp': 83010},
#  34: {'brand_amount': 227,
#   'brand_price_max': 2900,
#   'brand_price_min': 60,
#   'brand_price_median': 999.0,
#   'brand_price_mean': 1021.0396475770925,
#   'brand_price_sum': 231776,
#   'brand_price_std': 554.1184445887935,
#   'brand_price_ptp': 2840},
#  35: {'brand_amount': 180,
#   'brand_price_max': 28900,
#   'brand_price_min': 50,
#   'brand_price_median': 950.0,
#   'brand_price_mean': 1655.4277777777777,
#   'brand_price_sum': 297977,
#   'brand_price_std': 3325.9333650788553,
#   'brand_price_ptp': 28850},
#  36: {'brand_amount': 228,
#   'brand_price_max': 20900,
#   'brand_price_min': 150,
#   'brand_price_median': 2250.0,
#   'brand_price_mean': 3578.9517543859647,
#   'brand_price_sum': 816001,
#   'brand_price_std': 3922.7153885654966,
#   'brand_price_ptp': 20750},
#  37: {'brand_amount': 333,
#   'brand_price_max': 86500,
#   'brand_price_min': 550,
#   'brand_price_median': 13400.0,
#   'brand_price_mean': 16300.129129129129,
#   'brand_price_sum': 5427943,
#   'brand_price_std': 13542.028621706084,
#   'brand_price_ptp': 85950},
#  38: {'brand_amount': 65,
#   'brand_price_max': 8999,
#   'brand_price_min': 99,
#   'brand_price_median': 2850.0,
#   'brand_price_mean': 3317.230769230769,
#   'brand_price_sum': 215620,
#   'brand_price_std': 2140.083145064336,
#   'brand_price_ptp': 8900},
#  39: {'brand_amount': 9,
#   'brand_price_max': 14500,
#   'brand_price_min': 750,
#   'brand_price_median': 1900.0,
#   'brand_price_mean': 4386.666666666667,
#   'brand_price_sum': 39480,
#   'brand_price_std': 5520.867232600327,
#   'brand_price_ptp': 13750}}

# %%
brand_stats = pd.DataFrame(all_info).T.reset_index().rename(columns={'index':'brand'})
train_data = train_data.merge(brand_stats, how='left', on='brand')
test = test.merge(brand_stats, how='left', on='brand')

# %% [markdown]
# ## 特征选择，删除['SaleID', 'name', 'seller', 'regDate', 'creatDate', 'offerType', 'price']列

# %%
# 特征选择
drop_cols = ['SaleID', 'name', 'seller', 'regDate', 'creatDate', 'offerType', 'price']
feature_cols = [col for col in train_data.columns if col not in drop_cols]
feature_cols
# Out:
# ['model',
#  'brand',
#  'bodyType',
#  'fuelType',
#  'gearbox',
#  'power',
#  'kilometer',
#  'notRepairedDamage',
#  'regionCode',
#  'v_0',
#  'v_1',
#  'v_2',
#  'v_3',
#  'v_4',
#  'v_5',
#  'v_6',
#  'v_7',
#  'v_8',
#  'v_9',
#  'v_10',
#  'v_11',
#  'v_12',
#  'v_13',
#  'v_14',
#  'regDate_year',
#  'regDate_month',
#  'regDate_day',
#  'creatDate_year',
#  'creatDate_month',
#  'creatDate_day',
#  'regDate_diff',
#  'creatDate_diff',
#  'brand_amount',
#  'brand_price_max',
#  'brand_price_min',
#  'brand_price_median',
#  'brand_price_mean',
#  'brand_price_sum',
#  'brand_price_std',
#  'brand_price_ptp']

# %% [markdown]
# ## 数据格式转换

# %%
# 查看数值类型
numerical_cols = train_data.select_dtypes(exclude='object').columns
# 查看分类类型
categorical_cols = train_data.select_dtypes(include='object').columns
print(numerical_cols,categorical_cols)
# Out:
# Index(['SaleID', 'name', 'regDate', 'model', 'brand', 'bodyType', 'fuelType',
#        'gearbox', 'power', 'kilometer', 'regionCode', 'seller', 'offerType',
#        'creatDate', 'price', 'v_0', 'v_1', 'v_2', 'v_3', 'v_4', 'v_5', 'v_6',
#        'v_7', 'v_8', 'v_9', 'v_10', 'v_11', 'v_12', 'v_13', 'v_14',
#        'regDate_diff', 'creatDate_diff', 'brand_amount', 'brand_price_max',
#        'brand_price_min', 'brand_price_median', 'brand_price_mean',
#        'brand_price_sum', 'brand_price_std', 'brand_price_ptp'],
#       dtype='object') Index(['notRepairedDamage', 'regDate_year', 'regDate_month', 'regDate_day',
#        'creatDate_year', 'creatDate_month', 'creatDate_day'],
#       dtype='object')

# %%
# 转换数据类型
import warnings
warnings.filterwarnings('ignore')
#X_data.info()
train_data['notRepairedDamage'] = train_data['notRepairedDamage'].astype('float64')
test['notRepairedDamage'] = test['notRepairedDamage'].astype('float64')

# %%
train_data['regDate_year'] = train_data['regDate_year'].astype('int64')
test['regDate_year'] = test['regDate_year'].astype('int64')

train_data['regDate_month'] = train_data['regDate_month'].astype('int64')
test['regDate_month'] = test['regDate_month'].astype('int64')

train_data['regDate_day'] = train_data['regDate_day'].astype('int64')
test['regDate_day'] = test['regDate_day'].astype('int64')

train_data['creatDate_year'] = train_data['creatDate_year'].astype('int64')
test['creatDate_year'] = test['creatDate_year'].astype('int64')

train_data['creatDate_month'] = train_data['creatDate_month'].astype('int64')
test['creatDate_month'] = test['creatDate_month'].astype('int64')

train_data['creatDate_day'] = train_data['creatDate_day'].astype('int64')
test['creatDate_day'] = test['creatDate_day'].astype('int64')

# %%
# 查看数值类型
numerical_cols = train_data.select_dtypes(exclude='object').columns
# 查看分类类型
categorical_cols = train_data.select_dtypes(include='object').columns
print(numerical_cols,categorical_cols)
# Out:
# Index(['SaleID', 'name', 'regDate', 'model', 'brand', 'bodyType', 'fuelType',
#        'gearbox', 'power', 'kilometer', 'notRepairedDamage', 'regionCode',
#        'seller', 'offerType', 'creatDate', 'price', 'v_0', 'v_1', 'v_2', 'v_3',
#        'v_4', 'v_5', 'v_6', 'v_7', 'v_8', 'v_9', 'v_10', 'v_11', 'v_12',
#        'v_13', 'v_14', 'regDate_year', 'regDate_month', 'regDate_day',
#        'creatDate_year', 'creatDate_month', 'creatDate_day', 'regDate_diff',
#        'creatDate_diff', 'brand_amount', 'brand_price_max', 'brand_price_min',
#        'brand_price_median', 'brand_price_mean', 'brand_price_sum',
#        'brand_price_std', 'brand_price_ptp'],
#       dtype='object') Index([], dtype='object')

# %% [markdown]
# ## 创建模型

# %%
# 提取特征列
X_data = train_data[feature_cols]
Y_data = train_data['price']
X_test = test[feature_cols]

# %%
import numpy as np
# 定一个统计函数，用于统计某字段的特征
def show_stats(data):
    print('min: ', np.min(data))
    print('max: ', np.max(data))
    # ptp = max - min
    print('ptp: ', np.ptp(data))
    print('mean: ', np.mean(data))
    print('std: ', np.std(data))
    print('var: ', np.var(data))
# 查看price
show_stats(Y_data)
# Out:
# min:  11
# max:  99999
# ptp:  99988
# mean:  5923.327333333334
# std:  7501.973469876438
# var:  56279605.94272992

# %% [markdown]
# #### 5折交叉验证+XGBoost

# %%
# 具体几个子模型，可以测试，可以试一下10折
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_absolute_error
def ensemble_model(clf, train_x, train_y, test, n):
    # 采用五折交叉验证
    sk = StratifiedKFold(n_splits=n, shuffle=True, random_state=2021)
    mean_mae = 0
    result = []
    for k, (train_index, val_index) in enumerate(sk.split(train_x, train_y)):
        # 使用sk，得到训练集，验证集
        train_x_real = train_x.iloc[train_index]
        train_y_real = train_y.iloc[train_index]
        val_x = train_x.iloc[val_index]
        val_y = train_y.iloc[val_index]
        # 子模型训练
        clf = clf.fit(train_x_real, train_y_real)
        val_y_pred = clf.predict(val_x)
        # 子模型评估
        mae_val = mean_absolute_error(val_y,val_y_pred)
        print(f'第{k+1}个子模型MAE{mae_val}')
        mean_mae += mae_val/n
        # 使用子模型对测试集进行预测
        test_y_pred = clf.predict(X_test)
        result.append(test_y_pred)
    print(mean_mae)
    # 最终结果 = 5个子模型的平均值
    mean_result = sum(result) / n
    return mean_result

# %%
import xgboost as xgb
# 祖传参数
model_xgb = xgb.XGBRegressor(
        max_depth=6, learning_rate=0.1, n_estimators=15000, 
        early_stopping_rounds=200,
        objective='reg:linear', 
        tree_method='gpu_hist',
        subsample=0.8, colsample_bytree=0.8, 
        min_child_samples=3, eval_metric='mae', reg_lambda=0.5
    )

# model_xgb.fit(X_data, Y_data)
y_pred_xgb = ensemble_model(model_xgb, X_data, Y_data, X_test, 10)
# Out:
# [07:50:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [07:50:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "early_stopping_rounds", "min_child_samples" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 第1个子模型MAE498.88858030522266
# [08:06:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [08:06:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "early_stopping_rounds", "min_child_samples" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 第2个子模型MAE513.8890718258699
# [08:23:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [08:23:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "early_stopping_rounds", "min_child_samples" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 第3个子模型MAE515.6175165771803
# [08:40:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [08:40:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "early_stopping_rounds", "min_child_samples" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 第4个子模型MAE509.5598602485021
# [08:56:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [08:56:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "early_stopping_rounds", "min_child_samples" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 第5个子模型MAE498.774430959785
# [09:13:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [09:13:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "early_stopping_rounds", "min_child_samples" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 第6个子模型MAE505.8820403861602
# [09:30:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [09:30:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "early_stopping_rounds", "min_child_samples" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 第7个子模型MAE509.626504897817
# [09:46:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [09:46:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "early_stopping_rounds", "min_child_samples" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 第8个子模型MAE503.6025510570367
# [10:03:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [10:03:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "early_stopping_rounds", "min_child_samples" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 第9个子模型MAE506.209710468334
# [10:20:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [10:20:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "early_stopping_rounds", "min_child_samples" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 第10个子模型MAE509.09466575043996
# 507.1144932476348

# %%
show_stats(y_pred_xgb)
# Out:
# min:  -710.5499
# max:  90757.6
# ptp:  91468.15
# mean:  5912.983
# std:  7388.3213
# var:  54587290.0

# %%
y_pred_xgb[y_pred_xgb<0] = 11

# %% [markdown]
# #### nn

# %%
# 数据归一化
from sklearn.preprocessing import MinMaxScaler
mm = MinMaxScaler()
x = mm.fit_transform(X_data)
x_test = mm.transform(X_test)
y = Y_data.values

# %%
from tensorflow import keras

model_nn = keras.Sequential([
    # 250维度，定义向量的长度
    keras.layers.Dense(320,activation='relu',input_shape=[len(feature_cols)]),
    keras.layers.Dense(160,activation='relu'),
    keras.layers.Dense(80,activation='relu'),
    # 最终输出结果是price
    keras.layers.Dense(1)
])
# 设置优化器
model_nn.compile(loss='mean_absolute_error', optimizer='Adam')
# 模型训练
model_nn.fit(x, y, batch_size=2048, epochs=300)
# Out:
# Epoch 1/300
# 74/74 [==============================] - 2s 19ms/step - loss: 5820.5059
# Epoch 2/300
# 74/74 [==============================] - 1s 18ms/step - loss: 4239.9122
# Epoch 3/300
# 74/74 [==============================] - 1s 18ms/step - loss: 3834.2153
# Epoch 4/300
# 74/74 [==============================] - 1s 19ms/step - loss: 2423.8363
# Epoch 5/300
# 74/74 [==============================] - 1s 18ms/step - loss: 1549.2013
# Epoch 6/300
# 74/74 [==============================] - 1s 18ms/step - loss: 1321.8679
# Epoch 7/300
# 74/74 [==============================] - 1s 19ms/step - loss: 1202.4919
# Epoch 8/300
# 74/74 [==============================] - 1s 19ms/step - loss: 1127.2075
# Epoch 9/300
# 74/74 [==============================] - 1s 19ms/step - loss: 1069.4508
# Epoch 10/300
# 74/74 [==============================] - 1s 20ms/step - loss: 1025.1267
# Epoch 11/300
# 74/74 [==============================] - 1s 19ms/step - loss: 985.6681
